# %%
def get_state(ids):
    counts = {}
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge_ids(ids, pair, idx):
    newids=[]
    i = 0
    while i < len(ids):
        if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
            newids.append(idx)
            i += 2
        else:
            newids.append(ids[i])
            i += 1
    
    return newids

# %%
import json

with open('vocab.json', 'r') as f:
    file = json.load(f)

# %%
# for key, value in file.items():
#     print(value)

# %%
def encode(text):
    ids = list(text.encode("utf-8"))

    while True:
        stats = get_state(ids)
        pair_key = lambda p: f"{p[0]},{p[1]}"

        pair = min(stats, key=lambda p: file.get(pair_key(p), float("inf")))

        if pair_key(pair) not in file:
            break   
        idx = file[pair_key(pair)]
        ids = merge_ids(ids, pair, idx)

    return ids

print(encode('yes yes'))
# Out:
# [121, 345, 121, 280]

# %%
vocab = {i: bytes([i]) for i in range(256)}

for key, idx in file.items():
    p0, p1 = map(int, key.split(','))
    vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
    tokens = b"".join(vocab[idx] for idx in ids)
    return tokens.decode("utf-8", errors="replace")

# %%
import torch

model = torch.load("mini-gpt-10k.pth", weights_only=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 import torch
# ----> 3 model = torch.load("mini-gpt-10k.pth", weights_only=False)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\serialization.py:1530, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1528             except pickle.UnpicklingError as e:
#    1529                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1530         return _load(
#    1531             opened_zipfile,
#    1532             map_location,
#    1533             pickle_module,
#    1534             overall_storage=overall_storage,
#    1535             **pickle_load_args,
#    1536         )
#    1537 if mmap:
#    1538     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# ...
